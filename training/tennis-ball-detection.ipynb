# %%
import shutil

# %%
shutil.move("tennis-ball-detection/train",
"tennis-ball-detection/tennis-ball-detection/train",
)
shutil.move("tennis-ball-detection/test",
"tennis-ball-detection/tennis-ball-detection/test",
)
shutil.move("tennis-ball-detection/valid",
"tennis-ball-detection/tennis-ball-detection/valid",
)
# Out:
# 'tennis-ball-detection/tennis-ball-detection/valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data="C:/Users/gauth/Desktop/courses/capstone/project-code/capstone-project/ML/training/tennis-ball-detection/tennis-ball-detection/data.yaml" epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.14 🚀 Python-3.11.9 torch-2.4.1+cpu CPU (13th Gen Intel Core(TM) i7-13650HX)
#   0%|          | 0.00/755k [00:00<?, ?B/s]
# 100%|██████████| 755k/755k [00:00<00:00, 30.7MB/s]
#
# train: Scanning C:\Users\gauth\Desktop\courses\capstone\project-code\capstone-project\ML\training\tennis-ball-detection\tennis-ball-detection\train\labels...:   0%|          | 0/428 [00:00<?, ?it/s]
# train: Scanning C:\Users\gauth\Desktop\courses\capstone\project-code\capstone-project\ML\training\tennis-ball-detection\tennis-ball-detection\train\labels... 1 images, 0 backgrounds, 0 corrupt:   0%|          | 1/428 [00:00<01:18,  5.42it/s]
# train: Scanning C:\Users\gauth\Desktop\courses\capstone\project-code\capstone-project\ML\training\tennis-ball-detection\tennis-ball-detection\train\labels... 33 images, 0 backgrounds, 0 corrupt:   8%|▊         | 33/428 [00:00<00:02, 139.96it/s]
# ...
